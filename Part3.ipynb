# %% [markdown]
# ### The persistent student

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def no_of_attempts(p_pass):
     z = np.random.geometric(p=p_pass, size=10000)
     return z
a=no_of_attempts(0.4)
a
# Out:
# array([2, 2, 1, ..., 3, 1, 8])

# %%
plt.hist(a)
# Out:
# (array([6.464e+03, 2.233e+03, 8.290e+02, 3.070e+02, 6.400e+01, 6.700e+01,
#         2.200e+01, 1.100e+01, 0.000e+00, 3.000e+00]),
#  array([ 1. ,  2.8,  4.6,  6.4,  8.2, 10. , 11.8, 13.6, 15.4, 17.2, 19. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Heights and weights

# %%
male_weight=np.random.normal(90,10,25)
male_height=np.random.normal(140,15,25)

# %%
fmale_weight=np.random.normal(60,5,25)
fmale_height=np.random.normal(195,10,25)

# %%
gender=[]
for i in range(20):
    gender.append("M")
for i in range(30):
    gender.append("F")
gen=pd.Series(gender,name="Gender")
weights=[]
weights.extend(male_weight)
weights.extend(fmale_weight)
heights=[]
heights.extend(male_height)
heights.extend(fmale_height)
df=pd.DataFrame({'Gender':gen,'Weights':weights,'Heights':heights})

# %%
df
# Out:
#    Gender     Weights     Heights
# 0       M  100.006308  148.207134
# 1       M   73.905029  124.550008
# 2       M   82.836414  117.235401
# 3       M   95.272610  137.898009
# 4       M   92.351823  124.597524
# 5       M   87.398382  127.557878
# 6       M   75.492503  131.095336
# 7       M   83.331968  111.529953
# 8       M   88.753872  147.023655
# 9       M   94.825254  122.100143
# 10      M   94.515534  135.603759
# 11      M   87.165091   97.403717
# 12      M   83.346626  176.389469
# 13      M   94.454977  106.083433
# 14      M   86.370714  139.602477
# 15      M   95.363275  155.999208
# 16      M   94.588020  141.143045
# 17      M   95.033385  153.266967
# 18      M   88.152144  137.896485
# 19      M   89.523779  146.934596
# 20      F   94.130770  140.813555
# 21      F   81.544739  134.829793
# 22      F   91.659958  135.171493
# 23      F   89.632455  164.303875
# 24      F   90.628576  149.303450
# 25      F   60.924120  187.384538
# 26      F   58.849460  177.539150
# 27      F   54.108520  187.704823
# 28      F   62.899223  195.194296
# 29      F   62.613196  189.198194
# 30      F   58.995794  181.715374
# 31      F   65.217794  190.822388
# 32      F   62.292833  188.687676
# 33      F   62.989258  203.421557
# 34      F   58.910811  216.447035
# 35      F   57.259665  188.135442
# 36      F   67.926030  189.256457
# 37      F   54.119818  208.295768
# 38      F   56.706663  205.447935
# 39      F   59.056973  214.598924
# 40      F   67.606520  199.827377
# 41      F   50.140508  188.288877
# 42      F   58.391835  210.301673
# 43      F   63.259408  199.720127
# 44      F   56.569429  187.261924
# 45      F   66.079942  181.187317
# 46      F   56.215615  200.364441
# 47      F   66.438715  186.889914
# 48      F   57.975514  212.892056
# 49      F   50.017140  201.773532
